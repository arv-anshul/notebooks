# %% [markdown]
# # Search Keywords Classification
#
# **This is a task I was worked while in internship.** I have used `text-classification` technique for this but didn't get
# the work done (because it was my first working with BERT).
#
# Now, after internship I am thinking to work on this once more but with some different and efficient approach.
# Previously, I fine-tunned BERT model to classify keywords into (BRAND, LOCATION, COMPETITION and COMPARISION) labels but
# this doesn't fulfill our needs because we also have to assign a score to each keyword to group them in better-to-good
# hierarchy.
#
# I think BERT is a heavy way to achieve this instead we can use **hybrid approach of Rule based and Machine Learning
# technique** to classify them and assign a score to each of them.

# %% [markdown]
# ---

# %% [markdown]
# ### Hybrid Approach: Rule-Based + Machine Learning
#
# > 🤖 Suggestion from ChatGPT
#
# You can combine **rule-based methods** with **machine learning** for keyword classification. This can work especially
# well in tasks like **location recognition**, where places can often be identified by specific keywords or patterns.
#
# 1. **Rule-Based Methods**
#
# Use regular expressions (e.g., patterns for brands like `"Apple"`, `"Samsung"`) or dictionaries of location names to
# automatically tag certain entities. Combine such rule-based classification with machine learning methods to reduce the
# complexity of handling rare or ambiguous entities.
#
# 2. **Conditional Random Fields (CRF)**[^1]
#
# For token-level classification, CRF models are another technique used in NER tasks. They can take into account the
# context of neighboring tokens to improve classification. You can use a **CRF layer** on top of BERT or other
# transformers.
#
# [^1]: Doesn't understand the technique

# %% [markdown]
# ---

# %% [markdown]
# _Currently I don't know how to integrate ML here,_ but I am sure this approach will work and faster than previous one
# because:
#
# 1. I will ask user to input their interest of **brand, location, competition** keywords.
#
#    ```json
#    {
#      "brand": ["apple", "iphone", "macbook", "airpod"],
#      "location": ["patna", "bihar"],
#      "competition": ["samsung", "redmi", "vivo", "galaxy 23", "samsung galaxy"]
#    }
#    ```
#
#    **Using these I can parse the keywords and assign the labels.**
#
#    ```json
#    {
#      "buy iphone 13": ["BRAND"],
#      "iphone 13 in patna": ["BRAND", "LOCATION"],
#      "price of samsung galaxy 21 FE": ["COMPETITION"]
#    }
#    ```
#
# 2. Using the same method, I can also tag keywords' **(PURCHASE, NAVIGATIONAL, COMPARISION, INFORMATIONAL)** intent.

# %%
import polars as pl
from polars import selectors as cs

# %%
pl.Config.set_fmt_str_lengths(50)
# Out:
# polars.config.Config

# %%
__fav_kwds = ["iphone", "redmi", "samsung", "galaxy", "vivo"]
kwds = (
    pl.scan_csv("data/samsung_galaxy.csv")
    .filter(
        pl.col("keyword").str.contains_any(__fav_kwds, ascii_case_insensitive=True),
    )
    .filter(pl.col("keyword").is_first_distinct())
)
kwds.head().collect()
# Out:
# shape: (5, 1)
# ┌─────────────────────────────────────────────────────┐
# │ keyword                                             │
# │ ---                                                 │
# │ str                                                 │
# ╞═════════════════════════════════════════════════════╡
# │ samsung m & a series                                │
# │ samsung smartplaza bharath electronics & appliance… │
# │ vivo camera & music                                 │
# │ best samsung's series                               │
# │ iphone 13 0                                         │
# └─────────────────────────────────────────────────────┘

# %% [markdown]
# ### Add category based columns

# %%
input_kwds = {
    "brand": ["apple", "iphone", "macbook", "airpod"],
    "location": ["patna", "bihar"],
    "competition": ["samsung", "redmi", "vivo", "galaxy 23", "samsung galaxy"],
}

# %%
kwds = kwds.with_columns(
    *[
        pl.col("keyword")
        .str.contains_any(v, ascii_case_insensitive=True)
        .alias(f"cat_{k}")
        for k, v in input_kwds.items()
    ],
)
kwds.filter(
    pl.col("cat_brand"),
    pl.col("cat_competition"),
).collect()
# Out:
# shape: (15, 4)
# ┌───────────────────────────────────────────────┬───────────┬──────────────┬─────────────────┐
# │ keyword                                       ┆ cat_brand ┆ cat_location ┆ cat_competition │
# │ ---                                           ┆ ---       ┆ ---          ┆ ---             │
# │ str                                           ┆ bool      ┆ bool         ┆ bool            │
# ╞═══════════════════════════════════════════════╪═══════════╪══════════════╪═════════════════╡
# │ samsung with 3 camera like iphone             ┆ true      ┆ false        ┆ true            │
# │ samsung galaxy watch 4 compatible with iphone ┆ true      ┆ false        ┆ true            │
# │ samsung galaxy watch 4 iphone                 ┆ true      ┆ false        ┆ true            │
# │ samsung watch 4 iphone                        ┆ true      ┆ false        ┆ true            │
# │ samsung airpods                               ┆ true      ┆ false        ┆ true            │
# │ …                                             ┆ …         ┆ …            ┆ …               │
# │ samsung smart switch iphone                   ┆ true      ┆ false        ┆ true            │
# │ samsung to iphone                             ┆ true      ┆ false        ┆ true            │
# │ iphone to samsung tv                          ┆ true      ┆ false        ┆ true            │
# │ samsung watch iphone                          ┆ true      ┆ false        ┆ true            │
# │ samsung watch with iphone                     ┆ true      ┆ false        ┆ true            │
# └───────────────────────────────────────────────┴───────────┴──────────────┴─────────────────┘

# %% [markdown]
# ### Add intent based columns

# %%
# these are some keywords which are common in respective intent
intent_kwds = {
    "transactional": ["price", "buy", "under", "flipkart", "amazon"],
    "comparison": [" vs ", "&", "versus", " and "],
    "navigational": ["near"],
    "informational": ["antutu", "camera", "best"],
}

# %%
kwds = kwds.with_columns(
    *[
        pl.col("keyword")
        .str.contains_any(v, ascii_case_insensitive=True)
        .alias(f"int_{k}")
        for k, v in intent_kwds.items()
    ],
).with_columns(
    # Represent keywords which have no intent
    pl.any_horizontal(cs.starts_with("int_")).not_().alias("no_intent"),
)

kwds.filter(pl.col("no_intent")).collect().sample(20)
# Out:
# shape: (20, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ keyword   ┆ cat_brand ┆ cat_locat ┆ cat_compe ┆ … ┆ int_compa ┆ int_navig ┆ int_infor ┆ no_inten │
# │ ---       ┆ ---       ┆ ion       ┆ tition    ┆   ┆ rison     ┆ ational   ┆ mational  ┆ t        │
# │ str       ┆ bool      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ bool      ┆ bool      ┆   ┆ bool      ┆ bool      ┆ bool      ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ galaxy    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ a05       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ galaxy s7 ┆ false     ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ galaxy 5g ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mobile    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 22        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ iphone    ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 12mini    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ vivo 8    ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ pro       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ c7 pro    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ sabse     ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mehnga    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ phone     ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung s ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 5g        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ s7        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ### Assign score _(manual approach)_
#
# **Score Types**
#
# 1. **Counter Score:** Add 1 point for each `true` value of different category and intent of keyword.
# 2. **Proportional Score**: A pre-defined points dictionary which used to assign score if the category or intent value is
#    `true`.

# %%
# Assign Counter Score
counter_scores = kwds.select(
    "keyword",
    cat_score_counter=pl.sum_horizontal(cs.starts_with("cat_")),
    int_score_counter=pl.sum_horizontal(cs.starts_with("int_")),
)
counter_scores.head().collect()
# Out:
# shape: (5, 3)
# ┌─────────────────────────────────────────────────────┬───────────────────┬───────────────────┐
# │ keyword                                             ┆ cat_score_counter ┆ int_score_counter │
# │ ---                                                 ┆ ---               ┆ ---               │
# │ str                                                 ┆ u32               ┆ u32               │
# ╞═════════════════════════════════════════════════════╪═══════════════════╪═══════════════════╡
# │ samsung m & a series                                ┆ 1                 ┆ 1                 │
# │ samsung smartplaza bharath electronics & appliance… ┆ 1                 ┆ 1                 │
# │ vivo camera & music                                 ┆ 1                 ┆ 2                 │
# │ best samsung's series                               ┆ 1                 ┆ 1                 │
# │ iphone 13 0                                         ┆ 1                 ┆ 0                 │
# └─────────────────────────────────────────────────────┴───────────────────┴───────────────────┘

# %%
print(counter_scores.collect().get_column("cat_score_counter").value_counts())
print(counter_scores.collect().get_column("int_score_counter").value_counts())
# Out:
# shape: (3, 2)
# ┌───────────────────┬───────┐
# │ cat_score_counter ┆ count │
# │ ---               ┆ ---   │
# │ u32               ┆ u32   │
# ╞═══════════════════╪═══════╡
# │ 0                 ┆ 886   │
# │ 1                 ┆ 10972 │
# │ 2                 ┆ 15    │
# └───────────────────┴───────┘
# shape: (4, 2)
# ┌───────────────────┬───────┐
# │ int_score_counter ┆ count │
# │ ---               ┆ ---   │
# │ u32               ┆ u32   │
# ╞═══════════════════╪═══════╡
# │ 0                 ┆ 8019  │
# │ 1                 ┆ 3709  │
# │ 2                 ┆ 144   │
# │ 3                 ┆ 1     │
# └───────────────────┴───────┘

# %%
# Proportional Score dictionary
proportional_score_dict = {
    "cat_brand": 7,
    "cat_location": 6,
    "cat_competition": 5,
    "int_transactional": 4,
    "int_navigational": 3,
    "int_comparison": 2,
    "int_informational": 1,
}

# %%
proportional_scores = kwds.with_columns(
    *[
        pl.col(k).replace_strict(True, v, default=0, return_dtype=pl.UInt8)
        for k, v in proportional_score_dict.items()
    ],
).select(
    "keyword",
    int_score_proportional=pl.sum_horizontal(cs.starts_with("int_")),
    cat_score_proportional=pl.sum_horizontal(cs.starts_with("cat_")),
)
proportional_scores.head().collect()
# Out:
# shape: (5, 3)
# ┌──────────────────────────────────────────┬────────────────────────┬────────────────────────┐
# │ keyword                                  ┆ int_score_proportional ┆ cat_score_proportional │
# │ ---                                      ┆ ---                    ┆ ---                    │
# │ str                                      ┆ u8                     ┆ u8                     │
# ╞══════════════════════════════════════════╪════════════════════════╪════════════════════════╡
# │ samsung m & a series                     ┆ 2                      ┆ 5                      │
# │ samsung smartplaza bharath electronics & ┆ 2                      ┆ 5                      │
# │ appliance…                               ┆                        ┆                        │
# │ vivo camera & music                      ┆ 3                      ┆ 5                      │
# │ best samsung's series                    ┆ 1                      ┆ 5                      │
# │ iphone 13 0                              ┆ 0                      ┆ 7                      │
# └──────────────────────────────────────────┴────────────────────────┴────────────────────────┘

# %%
# Merge both scores dataframe
scores = counter_scores.join(proportional_scores, on="keyword")
scores.head().collect()
# Out:
# shape: (5, 5)
# ┌───────────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ keyword           ┆ cat_score_counter ┆ int_score_counter ┆ int_score_proport ┆ cat_score_propor │
# │ ---               ┆ ---               ┆ ---               ┆ ional             ┆ tional           │
# │ str               ┆ u32               ┆ u32               ┆ ---               ┆ ---              │
# │                   ┆                   ┆                   ┆ u8                ┆ u8               │
# ╞═══════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ samsung m & a     ┆ 1                 ┆ 1                 ┆ 2                 ┆ 5                │
# │ series            ┆                   ┆                   ┆                   ┆                  │
# │ samsung           ┆ 1                 ┆ 1                 ┆ 2                 ┆ 5                │
# │ smartplaza        ┆                   ┆                   ┆                   ┆                  │
# │ bharath           ┆                   ┆                   ┆                   ┆                  │
# │ electronics &     ┆                   ┆                   ┆                   ┆                  │
# │ appliance…        ┆                   ┆                   ┆                   ┆                  │
# │ vivo camera &     ┆ 1                 ┆ 2                 ┆ 3                 ┆ 5                │
# │ music             ┆                   ┆                   ┆                   ┆                  │
# │ best samsung's    ┆ 1                 ┆ 1                 ┆ 1                 ┆ 5                │
# │ series            ┆                   ┆                   ┆                   ┆                  │
# │ iphone 13 0       ┆ 1                 ┆ 0                 ┆ 0                 ┆ 7                │
# └───────────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %% [markdown]
# ## Assign a final score to each keyword
#
# 1. Summation of Min-Max scaled scores to tackle the different range of score metrics.

# %%
def min_max_normalization(expr: pl.Expr, col: str):
    # Minimun is 0 here for all column
    return expr.sub(0).truediv(pl.max(col).sub(0))


scores = scores.with_columns(
    [
        pl.col(col).pipe(min_max_normalization, col)
        for col in scores.select(cs.matches("*_score_*")).collect_schema().names()
    ],
).with_columns(final_score=pl.sum_horizontal(cs.matches("*_score_*")))
scores.head().collect()
# Out:
# shape: (5, 6)
# ┌────────────────┬────────────────┬────────────────┬────────────────┬────────────────┬─────────────┐
# │ keyword        ┆ cat_score_coun ┆ int_score_coun ┆ int_score_prop ┆ cat_score_prop ┆ final_score │
# │ ---            ┆ ter            ┆ ter            ┆ ortional       ┆ ortional       ┆ ---         │
# │ str            ┆ ---            ┆ ---            ┆ ---            ┆ ---            ┆ f64         │
# │                ┆ f64            ┆ f64            ┆ f64            ┆ f64            ┆             │
# ╞════════════════╪════════════════╪════════════════╪════════════════╪════════════════╪═════════════╡
# │ samsung m & a  ┆ 0.5            ┆ 0.333333       ┆ 0.285714       ┆ 0.416667       ┆ 1.535714    │
# │ series         ┆                ┆                ┆                ┆                ┆             │
# │ samsung        ┆ 0.5            ┆ 0.333333       ┆ 0.285714       ┆ 0.416667       ┆ 1.535714    │
# │ smartplaza     ┆                ┆                ┆                ┆                ┆             │
# │ bharath        ┆                ┆                ┆                ┆                ┆             │
# │ electronics &  ┆                ┆                ┆                ┆                ┆             │
# │ appliance…     ┆                ┆                ┆                ┆                ┆             │
# │ vivo camera &  ┆ 0.5            ┆ 0.666667       ┆ 0.428571       ┆ 0.416667       ┆ 2.011905    │
# │ music          ┆                ┆                ┆                ┆                ┆             │
# │ best samsung's ┆ 0.5            ┆ 0.333333       ┆ 0.142857       ┆ 0.416667       ┆ 1.392857    │
# │ series         ┆                ┆                ┆                ┆                ┆             │
# │ iphone 13 0    ┆ 0.5            ┆ 0.0            ┆ 0.0            ┆ 0.583333       ┆ 1.083333    │
# └────────────────┴────────────────┴────────────────┴────────────────┴────────────────┴─────────────┘

# %%
scores.select("final_score").describe()
# Out:
# shape: (9, 2)
# ┌────────────┬─────────────┐
# │ statistic  ┆ final_score │
# │ ---        ┆ ---         │
# │ str        ┆ f64         │
# ╞════════════╪═════════════╡
# │ count      ┆ 11873.0     │
# │ null_count ┆ 0.0         │
# │ mean       ┆ 1.13796     │
# │ std        ┆ 0.498753    │
# │ min        ┆ 0.0         │
# │ 25%        ┆ 0.916667    │
# │ 50%        ┆ 0.916667    │
# │ 75%        ┆ 1.821429    │
# │ max        ┆ 2.916667    │
# └────────────┴─────────────┘

# %%
scores.filter(pl.col("final_score").eq(0)).select(
    pl.col("keyword").implode(),
).collect().head(30)["keyword"].item().to_list()
# Out:
# ['galaxy a 03',
#  'galaxy 03',
#  'galaxy 03s',
#  'galaxy fold 1',
#  'galaxy z fold 1',
#  'galaxy note 1',
#  'galaxy watch 1',
#  'galaxy note 10 5g',
#  'galaxy note 10 plus 5g',
#  'galaxy s 10 5g',
#  'galaxy a 10 s',
#  'galaxy s 10 e',
#  'galaxy 10',
#  'galaxy j 10',
#  'galaxy note 10 lite',
#  'galaxy note 10',
#  'galaxy note 10 plus',
#  'galaxy note 10 pro',
#  'galaxy note 10 ultra',
#  'galaxy s 10 plus',
#  'galaxy tab a 10.1',
#  'galaxy note 10.1',
#  'galaxy 11',
#  'galaxy note 11',
#  'galaxy a 12',
#  'galaxy 12',
#  'galaxy j 12',
#  'galaxy note 12',
#  'galaxy s21 fe 5g 128 gb',
#  'galaxy s20 fe 5g 128gb',
#  'galaxy s22 5g 128gb',
#  'galaxy a12 128gb',
#  'galaxy a23 128gb',
#  'galaxy a53 128gb',
#  'galaxy s22 plus 128gb',
#  'galaxy s22 128gb',
#  'galaxy s22 ultra 128gb',
#  'galaxy 13',
#  'galaxy 14 phone',
#  'galaxy book 2 360',
#  'galaxy book 2 pro 360',
#  'galaxy ace 2',
#  'galaxy active 2',
#  'galaxy watch active 2',
#  'galaxy beam 2',
#  'galaxy book 2',
#  'galaxy book 2 pro',
#  'galaxy buds 2',
#  'galaxy buds 2 pro',
#  'galaxy core 2',
#  'galaxy fit 2',
#  'galaxy flip 2',
#  'galaxy z flip 2',
#  'galaxy fold 2',
#  'galaxy z fold 2',
#  'galaxy folder 2',
#  'galaxy grand 2',
#  'galaxy j7 prime 2',
#  'galaxy mega 2',
#  'galaxy mini 2',
#  'galaxy note 2',
#  'galaxy watch 2',
#  'galaxy s 20 fe 5g',
#  'galaxy note 20 5g',
#  'galaxy note 20 ultra 5g',
#  'galaxy s 20 5g',
#  'galaxy a 20',
#  'galaxy a 20 s',
#  'galaxy fe 20',
#  'galaxy j 20',
#  'galaxy note 20',
#  'galaxy note 20 series',
#  'galaxy note 20 ultra',
#  'galaxy s 20',
#  'galaxy s 20 ultra',
#  'galaxy a5 2015',
#  'galaxy tab a 2016',
#  'galaxy a3 2016',
#  'galaxy a5 2016',
#  'galaxy a7 2016',
#  'galaxy j1 2016',
#  'galaxy j5 2016',
#  'galaxy j7 2016',
#  'galaxy a3 2017',
#  'galaxy a5 2017',
#  'galaxy a7 2017',
#  'galaxy j3 2017',
#  'galaxy j7 2017',
#  'galaxy a7 2018',
#  'galaxy a8 2018',
#  'galaxy tab a 8.0 2019',
#  'galaxy tab a 2019',
#  'galaxy tab s6 lite 2022',
#  'new galaxy phone 2023',
#  'galaxy s 21 fe 5g',
#  'galaxy s 21 5g',
#  'galaxy s 21 ultra 5g',
#  'galaxy a 21',
#  'galaxy s 21 fe',
#  'galaxy 21s',
#  'galaxy note 21',
#  'galaxy note 21 ultra',
#  'galaxy s 21 plus',
#  'galaxy s 21',
#  'galaxy s 21 ultra',
#  'galaxy s 21fe',
#  'galaxy a 22 5g',
#  'galaxy a 22',
#  'galaxy 22',
#  'galaxy note 22',
#  'galaxy note 22 ultra',
#  'galaxy s 22 plus',
#  'galaxy s 22 series',
#  'galaxy s 22 ultra',
#  'galaxy ultra 22',
#  'galaxy x 22',
#  'galaxy a 23 5g',
#  'galaxy m 23 5g',
#  'galaxy note 23',
#  'galaxy note 23 ultra',
#  'galaxy z flip 3 256gb',
#  'galaxy z flip 4 256gb',
#  'galaxy a53 5g 256gb',
#  'galaxy s21 fe 5g 256gb',
#  'galaxy z fold3 5g 256gb',
#  'galaxy s21 5g 256gb',
#  'galaxy s21 fe 256gb',
#  'galaxy s22 plus 256gb',
#  'galaxy s21 256gb',
#  'galaxy s22 256gb',
#  'galaxy s22 ultra 256gb',
#  'galaxy z fold 3 5g',
#  'galaxy ace 3',
#  'galaxy tab active 3',
#  'galaxy watch active 3',
#  'galaxy beam 3',
#  'galaxy buds 3',
#  'galaxy fit 3',
#  'galaxy flip 3',
#  'galaxy z flip 3',
#  'galaxy fold 3',
#  'galaxy z fold 3',
#  'galaxy note 3 neo',
#  'galaxy note 3',
#  'galaxy s 3',
#  'galaxy series 3',
#  'galaxy watch 3',
#  'galaxy xcover 3',
#  'galaxy note 30',
#  'galaxy a 31',
#  'galaxy a 32',
#  'galaxy s 32',
#  'galaxy a 33',
#  'galaxy book pro 360',
#  'galaxy book2 360',
#  'galaxy book2 pro 360',
#  'galaxy watch 4 40mm',
#  'galaxy watch 4 classic 42mm',
#  'galaxy watch 4 44mm',
#  'galaxy watch 4 classic 46mm lte',
#  'galaxy watch 4 classic 46mm',
#  'galaxy watch 4 46mm',
#  'galaxy flip 4 5g',
#  'galaxy z fold 4 5g',
#  'galaxy ace 4',
#  'galaxy watch active 4',
#  'google assistant galaxy watch 4',
#  'galaxy watch 4 classic lte',
#  'galaxy watch 4 classic',
#  'galaxy watch 4 reliance digital',
#  'galaxy flip 4',
#  'galaxy z flip 4',
#  'galaxy fold 4',
#  'galaxy z fold 4',
#  'galaxy 4',
#  'galaxy watch 4 lte',
#  'galaxy note 4',
#  'galaxy s 4',
#  'galaxy smartwatch 4',
#  'smartwatch galaxy watch 4',
#  'galaxy tab 4',
#  'galaxy watch 4',
#  'galaxy xcover 4',
#  'galaxy watch 5 40mm',
#  'galaxy watch 42mm',
#  'galaxy watch 5 44mm',
#  'galaxy watch4 classic 46mm',
#  'galaxy watch 46mm',
#  'galaxy a13 4g',
#  'galaxy a22 4g',
#  'galaxy a32 4g',
#  'galaxy x cover 5',
#  'galaxy z flip 5',
#  'galaxy fold 5',
#  'galaxy z fold 5',
#  'galaxy 5',
#  'galaxy watch 5 pro lte',
#  'galaxy watch 5 lte',
#  'galaxy note 5',
#  'galaxy watch 5 pro',
#  'galaxy s 5',
#  'galaxy watch 5',
#  'galaxy xcover 5',
#  'galaxy a 50',
#  'galaxy a 51',
#  'galaxy s22 ultra 512gb',
#  'galaxy a 52 5g',
#  'galaxy a 52',
#  'galaxy m 52',
#  'galaxy a 52s 5g',
#  'galaxy a 52s',
#  'galaxy m 53 5g',
#  'galaxy a 53',
#  'galaxy a 54',
#  'galaxy note 9 5g',
#  'galaxy a series 5g',
#  'galaxy a03s 5g',
#  'galaxy a11 5g',
#  'galaxy a12 5g',
#  'galaxy a13 5g',
#  'galaxy a14 5g',
#  'galaxy a15 5g',
#  'galaxy a22 5g',
#  'galaxy a23 5g',
#  'galaxy a3 5g',
#  'galaxy a32 5g',
#  'galaxy a33 5g',
#  'galaxy a42 5g',
#  'galaxy a5 5g',
#  'galaxy a50 5g',
#  'galaxy a51 5g',
#  'galaxy a52 5g',
#  'galaxy a52 s 5g',
#  'galaxy a52s 5g',
#  'galaxy a53 5g',
#  'galaxy a54 5g',
#  'galaxy a71 5g',
#  'galaxy a72 5g',
#  'galaxy a73 5g',
#  'galaxy a90 5g',
#  'galaxy f23 5g',
#  'galaxy f42 5g',
#  'galaxy s21 fe 5g',
#  'galaxy tab s7 fe 5g',
#  'galaxy flip 5g',
#  'galaxy z flip 5g',
#  'galaxy z flip3 5g',
#  'galaxy z fold3 5g',
#  'galaxy 5g',
#  'galaxy m series 5g',
#  'galaxy m13 5g',
#  'galaxy m23 5g',
#  'galaxy m32 5g',
#  'galaxy m33 5g',
#  'galaxy m53 5g',
#  'galaxy note 5g',
#  'galaxy note ultra 5g',
#  'galaxy 5g phone',
#  'galaxy s10 5g',
#  'galaxy s20 5g',
#  'galaxy s20 ultra 5g',
#  'galaxy s20fe 5g',
#  'galaxy s21 5g',
#  'galaxy s21 ultra 5g',
#  'galaxy s21+ 5g',
#  'galaxy s21fe 5g',
#  'galaxy s22 5g',
#  'galaxy s22 ultra 5g',
#  'galaxy tab s8 5g',
#  'galaxy tab s8 ultra 5g',
#  'galaxy s9 5g',
#  'galaxy a5 6',
#  'galaxy j3 6',
#  'galaxy j5 6',
#  'galaxy note 6',
#  'galaxy pixel 6',
#  'galaxy xcover 6 pro',
#  'galaxy s 6',
#  'galaxy watch series 6',
#  'galaxy watch 6',
#  'galaxy xcover 6',
#  'galaxy tab a8 64gb',
#  'galaxy j 7',
#  'galaxy tab 7 lite',
#  'galaxy note 7',
#  'galaxy 7 pro',
#  'galaxy s 7',
#  'galaxy a 71',
#  'galaxy a 72',
#  'galaxy a 74',
#  'galaxy 8',
#  'galaxy note 8',
#  'galaxy s 8',
#  'galaxy tab 8',
#  'galaxy tab 8 ultra',
#  'galaxy tab a 8.0',
#  'galaxy 9',
#  'galaxy note 9',
#  'galaxy note 9 plus',
#  'galaxy a 90',
#  'all galaxy a series phones',
#  'all galaxy a series',
#  'awesome galaxy a',
#  'latest galaxy a series phone',
#  'latest galaxy a series',
#  'galaxy a series phones list',
#  'galaxy a series list',
#  'galaxy a series mobile',
#  'galaxy a series new phone',
#  'new galaxy a series',
#  'newest galaxy a series',
#  'galaxy tab a with s pen',
#  'galaxy a series phones',
#  'galaxy a quantum',
#  'galaxy a series',
#  'galaxy a series specs',
#  'galaxy tab a sm t510',
#  'galaxy tab a',
#  'galaxy a01 core',
#  'galaxy a01',
#  'galaxy a02s',
#  'galaxy a03 core',
#  'galaxy a03',
#  'galaxy a03s',
#  'galaxy a04',
#  'galaxy a04e',
#  'galaxy a04s',
#  'galaxy a10',
#  'galaxy a10e',
#  'galaxy a10s',
#  'galaxy a11',
#  'galaxy a12',
#  'galaxy a12 phone',
#  'galaxy a13 release date',
#  'galaxy a13',
#  'galaxy a13 phone',
#  'galaxy a14',
#  'galaxy a15',
#  'galaxy a2',
#  'galaxy a20 e',
#  'galaxy a20',
#  'galaxy a20e',
#  'galaxy a20s',
#  'galaxy a21',
#  'galaxy a21s',
#  'galaxy a22 g5',
#  'galaxy a22',
#  'galaxy a23',
#  'galaxy a3 core',
#  'galaxy a3',
#  'galaxy a30',
#  'galaxy a30s',
#  'galaxy a31',
#  'galaxy a32',
#  'galaxy a32 phone',
#  'galaxy a33',
#  'galaxy a34',
#  'galaxy a40',
#  'galaxy a41',
#  'galaxy a42',
#  'galaxy a5',
#  'galaxy a50',
#  'galaxy a50s',
#  'galaxy a51',
#  'galaxy a52',
#  'galaxy a52 s',
#  'galaxy a52s',
#  'galaxy a53 g5',
#  'galaxy a53',
#  'galaxy a53 phone',
#  'galaxy a53 series',
#  'galaxy a53s',
#  'galaxy a54',
#  'galaxy a5g',
#  'galaxy a6',
#  'galaxy a6 plus',
#  'galaxy tab a6',
#  'galaxy a6+',
#  'galaxy a7',
#  'galaxy a7 lite',
#  'galaxy tab a7 lite',
#  'galaxy tab a7',
#  'galaxy a70',
#  'galaxy a71',
#  'galaxy a72',
#  'galaxy a73',
#  'galaxy a74',
#  'galaxy a8',
#  'galaxy tab a8 lte',
#  'galaxy a8 plus',
#  'galaxy tab a8 series',
#  'galaxy a8 star',
#  'galaxy tab a8',
#  'tablet galaxy a8',
#  'galaxy a80',
#  'galaxy a9',
#  'galaxy a90',
#  'galaxy ace',
#  'galaxy j1 ace',
#  'galaxy active',
#  'galaxy watch active',
#  'galaxy watch active2',
#  'affordable galaxy phones',
#  'ai galaxy',
#  'all galaxy s models',
#  'all galaxy phones',
#  'all galaxy s series phones',
#  'all galaxy series',
#  'galaxy alpha',
#  'android galaxy',
#  'galaxy ao3 core',
#  'galaxy ao3',
#  'galaxy ao3s',
#  'galaxy home appliances',
#  'galaxy apps',
#  'galaxy beam',
#  'galaxy book',
#  'galaxy book go',
#  'galaxy book pro',
#  'galaxy book2',
#  'galaxy book2 pro',
#  'galaxy book2 pro series',
#  'galaxy book2 series',
#  'bts galaxy phone',
#  'galaxy buds',
#  'galaxy buds live',
#  'galaxy buds plus',
#  'galaxy buds pro',
#  'galaxy buds+',
#  'galaxy buds2',
#  'galaxy buds2 pro',
#  'galaxy c series',
#  'galaxy c7',
#  'galaxy c7 pro',
#  'galaxy c9 pro',
#  'cheap galaxy phones',
#  'galaxy chromebook go',
#  'galaxy watch classic',
#  'galaxy watch4 classic',
#  'compare galaxy phones',
#  'galaxy core',
#  'galaxy j2 core',
#  'galaxy j7 core',
#  'galaxy m01 core',
#  'galaxy core prime',
#  'galaxy s21 cost',
#  'galaxy s22 cost',
#  'galaxy x cover pro',
#  'current galaxy phone',
#  'galaxy device',
#  'galaxy digital watch',
#  'galaxy store download',
#  'galaxy s22 ultra dual sim',
#  'galaxy s duos',
#  'galaxy fit e',
#  'galaxy s10 e',
#  'galaxy e series',
#  'galaxy tab e',
#  'galaxy e5',
#  'galaxy e7',
#  'galaxy note edge',
#  'galaxy edge phone',
#  'galaxy s6 edge plus',
#  'galaxy s6 edge',
#  'galaxy s7 edge',
#  'galaxy s8 edge',
#  'galaxy s9 edge',
#  'galaxy s6 edge+',
#  'galaxy note fan edition',
#  'galaxy s20 fan edition',
#  'electronic galaxy',
#  'galaxy series explained',
#  'galaxy f series',
#  'galaxy f12',
#  'galaxy f13',
#  'galaxy f22',
#  'galaxy f23',
#  'galaxy f41',
#  'galaxy f62',
#  'galaxy fame',
#  'galaxy fe',
#  'galaxy note fe',
#  'galaxy s22 fe',
#  'galaxy s7 fe',
#  'galaxy tab s7 fe',
#  'galaxy fe series',
#  'find my galaxy phone',
#  'galaxy fit',
#  'galaxy flip',
#  'new galaxy flip phone',
#  'galaxy flip phone',
#  'galaxy z flip phone',
#  'galaxy flip series',
#  'galaxy z flip series',
#  'galaxy x flip',
#  'galaxy z flip',
#  'galaxy z3 flip',
#  'galaxy fold',
#  'galaxy fold phone',
#  'galaxy fold series',
#  'galaxy z fold series',
#  'galaxy z fold',
#  'galaxy fold z3',
#  'galaxy fold z4',
#  'galaxy z fold3',
#  'galaxy folder',
#  'galaxy',
#  'galaxy gear',
#  'galaxy golden',
#  'galaxy grand',
#  'galaxy grand neo',
#  'galaxy grand prime plus',
#  'galaxy grand prime',
#  'galaxy grand prime pro',
#  'galaxy note phones in order',
#  'galaxy phones in order',
#  'galaxy s phones in order',
#  'galaxy series in order',
#  'galaxy j',
#  'galaxy j max',
#  'galaxy j series phones',
#  'galaxy j series',
#  'galaxy j1',
#  'galaxy j1 mini',
#  'galaxy j1 mini prime',
#  'galaxy j2',
#  'galaxy j2 prime',
#  'galaxy j2 pro',
#  'galaxy j3',
#  'galaxy j3 prime',
#  'galaxy j3 pro',
#  'galaxy j4',
#  'galaxy j4 plus',
#  'galaxy j4+',
#  'galaxy j5',
#  'galaxy j5 prime',
#  'galaxy j5 pro',
#  'galaxy j6',
#  'galaxy j6 plus',
#  'galaxy j6+',
#  'galaxy j7',
#  'galaxy j7 max',
#  'galaxy j7 neo',
#  'galaxy j7 nxt',
#  'galaxy j7 prime',
#  'galaxy j7 pro',
#  'galaxy j8',
#  'galaxy k zoom',
#  'galaxy m series latest phone',
#  'galaxy s latest model',
#  'latest galaxy note',
#  'latest galaxy note series',
#  'latest galaxy phone',
#  'latest galaxy s series phone',
#  'latest galaxy s series',
#  'list of galaxy s phones',
#  'galaxy s series list',
#  'galaxy note lite',
#  'galaxy s10 lite',
#  'galaxy s6 lite',
#  'galaxy tab s6 lite',
#  'galaxy tab s7 lite',
#  'galaxy watch lte',
#  'galaxy m series phones',
#  'galaxy m series',
#  'galaxy m01',
#  'galaxy m02',
#  'galaxy m10',
#  'galaxy m11',
#  'galaxy m12',
#  'galaxy m13',
#  'galaxy m20',
#  'galaxy m21',
#  'galaxy m22',
#  'galaxy m30',
#  'galaxy m30s',
#  'galaxy m31',
#  'galaxy m31s',
#  'galaxy m32',
#  'galaxy m33',
#  'galaxy m50',
#  'galaxy m51',
#  'galaxy mega',
#  'galaxy mini',
#  'galaxy s3 mini',
#  'galaxy s4 mini',
#  'galaxy s5 mini',
#  'galaxy mobile',
#  'galaxy new mobile',
#  'galaxy mobile phones',
#  'galaxy s series mobile',
#  'galaxy models',
#  'galaxy new model',
#  'galaxy s models',
#  'galaxy s23 models',
#  'my galaxy',
#  'galaxy s3 neo',
#  'new galaxy',
#  'new galaxy note',
#  'new galaxy phone',
#  'the new galaxy phone',
#  'new galaxy s22',
#  'newest galaxy note',
#  'next galaxy phone',
#  'galaxy nexus',
#  'galaxy note',
#  'galaxy note phones',
#  'galaxy note series phones',
#  'galaxy note plus',
#  'galaxy note s10',
#  'galaxy note s20',
#  'galaxy note s20 ultra',
#  'galaxy note s22 ultra',
#  'galaxy note series',
#  'galaxy note ultra',
#  'galaxy note20 ultra',
#  'galaxy note3',
#  'galaxy note8',
#  'galaxy note9',
#  'galaxy on nxt',
#  'galaxy on5',
#  'galaxy on7',
#  'galaxy on7 prime',
#  'galaxy on7 pro',
#  'galaxy phones',
#  'galaxy s series phones',
#  'galaxy s21 phone',
#  'galaxy s22 phone',
#  'galaxy z series phones',
#  'upcoming galaxy phones',
#  'galaxy pixel',
#  'galaxy s plus',
#  'galaxy s10 plus',
#  'galaxy s2 plus',
#  'galaxy s20 plus',
#  'galaxy s22 plus',
#  'galaxy tab s7 plus',
#  'galaxy s8 plus',
#  'galaxy tab s8 plus',
#  'galaxy s9 plus',
#  'galaxy pro',
#  'galaxy watch5 pro',
#  'galaxy xcover pro',
#  'galaxy xcover6 pro',
#  'galaxy s range',
#  'galaxy tablet range',
#  'galaxy s series',
#  'galaxy tab s series',
#  'upcoming galaxy s series',
#  'galaxy tab s',
#  'galaxy s ultra',
#  'galaxy s1',
#  'galaxy s1 ultra',
#  'galaxy s10',
#  'galaxy s10 series',
#  'galaxy s10+',
#  'galaxy s10e',
#  'galaxy s11',
#  'galaxy s12',
#  'galaxy s13',
#  'galaxy s2',
#  'galaxy tab s2',
#  's20 galaxy',
#  'galaxy s20 se',
#  'galaxy s20 series',
#  'galaxy s20 ultra',
#  'galaxy s20+',
#  'galaxy s20fe',
#  'galaxy s21',
#  'galaxy s21 series',
#  'galaxy s21 ultra',
#  'galaxy s21+',
#  'galaxy s21fe',
#  'galaxy s22',
#  'galaxy s22 series',
#  'smartphone galaxy s22',
#  'galaxy s22 ultra',
#  'galaxy s22 ultra waterproof',
#  'galaxy s22+',
#  'galaxy s23',
#  'galaxy s23 series',
#  'the galaxy s23',
#  'galaxy s23 ultra',
#  'galaxy s23+',
#  'galaxy s3',
#  'galaxy tab s3',
#  'galaxy tab s4',
#  'galaxy s4 zoom',
#  'galaxy tab s5e',
#  'galaxy s6',
#  'galaxy tab s6',
#  'galaxy s7',
#  'galaxy s7 series',
#  'galaxy tab s7',
#  'galaxy tab s7+',
#  'galaxy s8',
#  'galaxy s8 series',
#  'galaxy tab s8 series',
#  'galaxy tab s8',
#  'galaxy tab s8 ultra',
#  'galaxy s8 tablet',
#  'galaxy s8 ultra',
#  'galaxy s8+',
#  'galaxy tab s8+',
#  'galaxy s9',
#  'galaxy s9 series',
#  'galaxy tab s9',
#  'galaxy s9+',
#  'semsem galaxy',
#  'serie galaxy',
#  'galaxy series',
#  'galaxy tab series',
#  'galaxy x series',
#  'galaxy xcover series',
#  'galaxy z series',
#  'galaxy shop',
#  'galaxy smart tag',
#  'galaxy smartphone',
#  'galaxy smartwatch',
#  'galaxy store',
#  'galaxy tab',
#  'galaxy tag',
#  'galaxy transfer',
#  'galaxy trend',
#  'galaxy ultra',
#  'galaxy watch',
#  'galaxy watch3',
#  'galaxy watch4',
#  'galaxy wearable',
#  'galaxy win',
#  'galaxy x',
#  'galaxy xcover',
#  'galaxy y',
#  'galaxy young',
#  'galaxy z',
#  'galaxy z3',
#  'galaxy z4',
#  'galaxya13',
#  'galaxya23',
#  'galaxys22 series']

# %% [markdown]
# ## Additional filtering on keywords
#
# We can apply additional filtering while deciding good keywords like:
#
# 1. If a keyword has only `cat_brand=true` and `no_intent=true` then it is like `"iphone 12"`/`"galaxy 21 FE"` which
#    there is no intent at all just searching for a product on internet. _It seem if we ignore them we don't loose much
#    requirement._
# 2. The same is **true for competition only keywords**.
#
# This filtering can lead to _removal of more than 30% of keywords_ that's why we must consider asking this to **a Domain
# Expert**.

# %%
# Keywords which has only brand and no intent
kwds.filter(
    pl.all_horizontal("cat_brand", "no_intent"),
    pl.any_horizontal(cs.starts_with("cat_").exclude("cat_brand")).not_(),
).collect()
# Out:
# shape: (706, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ keyword   ┆ cat_brand ┆ cat_locat ┆ cat_compe ┆ … ┆ int_compa ┆ int_navig ┆ int_infor ┆ no_inten │
# │ ---       ┆ ---       ┆ ion       ┆ tition    ┆   ┆ rison     ┆ ational   ┆ mational  ┆ t        │
# │ str       ┆ bool      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ bool      ┆ bool      ┆   ┆ bool      ┆ bool      ┆ bool      ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ iphone 13 ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ iphone 14 ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ iphone 0  ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 002       ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphone    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ new       ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphone 1  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ iphone5   ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphone6   ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphone7   ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphone8   ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ plus      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ types of  ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphones   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Keywords which has only competition and no intent
kwds.filter(
    pl.all_horizontal("cat_competition", "no_intent"),
    pl.any_horizontal(cs.starts_with("cat_").exclude("cat_competition")).not_(),
).collect()
# Out:
# shape: (6_559, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ keyword   ┆ cat_brand ┆ cat_locat ┆ cat_compe ┆ … ┆ int_compa ┆ int_navig ┆ int_infor ┆ no_inten │
# │ ---       ┆ ---       ┆ ion       ┆ tition    ┆   ┆ rison     ┆ ational   ┆ mational  ┆ t        │
# │ str       ┆ bool      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ bool      ┆ bool      ┆   ┆ bool      ┆ bool      ┆ bool      ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ galaxy a  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 01        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung a ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 01        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ vivo y 01 ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ galaxy a  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 02        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung a ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 02        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ vivoy33s  ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy33t  ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy53s  ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy73   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy76   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Keywords which has either brand or competition and no intent
kwds.filter(
    pl.any_horizontal("cat_brand", "cat_competition"),
    pl.col("no_intent"),
    pl.any_horizontal(
        cs.starts_with("cat_").exclude("cat_brand", "cat_competition"),
    ).not_(),
).collect()
# Out:
# shape: (7_279, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ keyword   ┆ cat_brand ┆ cat_locat ┆ cat_compe ┆ … ┆ int_compa ┆ int_navig ┆ int_infor ┆ no_inten │
# │ ---       ┆ ---       ┆ ion       ┆ tition    ┆   ┆ rison     ┆ ational   ┆ mational  ┆ t        │
# │ str       ┆ bool      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ bool      ┆ bool      ┆   ┆ bool      ┆ bool      ┆ bool      ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ iphone 13 ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ iphone 14 ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ iphone 0  ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ 002       ┆ true      ┆ false     ┆ false     ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ iphone    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ samsung   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ galaxy a  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 01        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ vivoy33s  ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy33t  ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy53s  ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy73   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# │ vivoy76   ┆ false     ┆ false     ┆ true      ┆ … ┆ false     ┆ false     ┆ false     ┆ true     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
